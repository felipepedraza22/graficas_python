# %% [markdown]
# <a href="https://colab.research.google.com/github/felipepedraza22/graficas_python/blob/main/graficas_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GRAFICAS CON LA LIBRERIA MATPLOTLIB
# ## GRAFICAS EN DOS DIMENSIONES

# %% [markdown]
# Gráficos de una lista

# %%
# importamos la libreria
#import matplolib.pyplot

from matplotlib.pyplot import plot, show, xlim, ylim, xticks

# %%
# Grafica No. 1

y = [1,2,3,4,5]

plot(y)
show()

# %%
# Grafica No. 2

y = [1,2,3,4,5]

plot(y, "*")
show()

# %%
# Grafica No. 3

y = [1,2,3,4,5]
x = [2,4,6,8,10]

plot(x, y, "*")
show()

# %%
# Frafica No. 4

# Grafica con limites

y = [1,2,3,4,5]
x = [2,4,6,8,10]

plot(x, y, "*")
xlim(-10, 10)
ylim(0,15)
show()

# %%
#Grafica No. 5

from numpy import linspace, pi, sin

x= linspace(-10*pi, 10*pi, 2560)
y= sin(x)

plot(x,y)
ylim(-2,2)
show()

# %%
#Grafica No.6
from numpy import linspace, pi, sin

x= linspace(-pi, pi, 256)
y= sin(x)

plot(x,y)
ylim(-2,2)
xticks([-pi,-pi/2,0,pi/2,pi],[r'$-\pi$',r'$-\pi/2$', r'$0$', r'$\pi/2$', r'$\pi$'])
show()
